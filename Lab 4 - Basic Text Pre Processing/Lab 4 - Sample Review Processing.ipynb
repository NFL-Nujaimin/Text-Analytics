# %%
import pandas as pd

# %%
data = pd.read_csv("SampleReview.csv")
data
# Out:
#                                               Review
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...

# %%
import string

# %%
def remove_punctuation(text):
    punctuation_free = ""
    for i in text:
        if i not in string.punctuation:
            punctuation_free += i
    return punctuation_free

# %%
data['clean_punctuation']= data['Review'].apply(remove_punctuation)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...

# %%
data['clean_lower']= data['clean_punctuation'].str.lower()
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...

# %%
import re

# %%
def remove_numbers(text):
    return re.sub("[\d-]",'',text)

# %%
data['clean_number'] = data['clean_lower'].apply(remove_numbers)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\3nauf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
data['token_data']= data['clean_number'].apply(word_tokenize)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...

# %%
from nltk.util import ngrams
data['bigrams'] = data['token_data'].apply(lambda x: list(ngrams(x, 2)))
data['trigrams'] = data['token_data'].apply(lambda x: list(ngrams(x, 3)))
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data  \
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...
#
#                                              bigrams  \
# 0   [(i, have), (have, a), (a, brown), (brown, cat)]
# 1  [(my, friend), (friend, has), (has, a), (a, wh...
# 2  [(my, brother), (brother, has), (has, a), (a, ...
# 3  [(the, apple), (apple, has), (has, turned), (t...
# 4  [(my, sister), (sister, eats), (eats, apple), ...
# 5  [(my, aunt), (aunt, makes), (makes, delicious)...
# 6  [(the, fluffy), (fluffy, dogs), (dogs, and), (...
#
#                                             trigrams
# 0  [(i, have, a), (have, a, brown), (a, brown, cat)]
# 1  [(my, friend, has), (friend, has, a), (has, a,...
# 2  [(my, brother, has), (brother, has, a), (has, ...
# 3  [(the, apple, has), (apple, has, turned), (has...
# 4  [(my, sister, eats), (sister, eats, apple), (e...
# 5  [(my, aunt, makes), (aunt, makes, delicious), ...
# 6  [(the, fluffy, dogs), (fluffy, dogs, and), (do...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\3nauf\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(text):
    output = []
    for i in text:
        if i not in stopwords:
            output.append(i)
    return output

# %%
data['clean_stopwords'] = data['token_data'].apply(remove_stopwords)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data  \
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...
#
#                                              bigrams  \
# 0   [(i, have), (have, a), (a, brown), (brown, cat)]
# 1  [(my, friend), (friend, has), (has, a), (a, wh...
# 2  [(my, brother), (brother, has), (has, a), (a, ...
# 3  [(the, apple), (apple, has), (has, turned), (t...
# 4  [(my, sister), (sister, eats), (eats, apple), ...
# 5  [(my, aunt), (aunt, makes), (makes, delicious)...
# 6  [(the, fluffy), (fluffy, dogs), (dogs, and), (...
#
#                                             trigrams  \
# 0  [(i, have, a), (have, a, brown), (a, brown, cat)]
# 1  [(my, friend, has), (friend, has, a), (has, a,...
# 2  [(my, brother, has), (brother, has, a), (has, ...
# 3  [(the, apple, has), (apple, has, turned), (has...
# 4  [(my, sister, eats), (sister, eats, apple), (e...
# 5  [(my, aunt, makes), (aunt, makes, delicious), ...
# 6  [(the, fluffy, dogs), (fluffy, dogs, and), (do...
#
#                           clean_stopwords
# 0                            [brown, cat]
# 1                    [friend, white, cat]
# 2                   [brother, white, car]
# 3                  [apple, turned, brown]
# 4       [sister, eats, apple, every, day]
# 5    [aunt, makes, delicious, apple, pie]
# 6  [fluffy, dogs, brown, hats, favorites]

# %%
from nltk.stem.porter import PorterStemmer

# %%
porter_stemmer = PorterStemmer()

# %%
def stemming(text):
    stem_text = []
    for word in text:
        stemmed_word = porter_stemmer.stem(word)
        stem_text.append(stemmed_word)
    return stem_text

# %%
data['clean_stemmed_porter'] = data['clean_stopwords'].apply(stemming)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data  \
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...
#
#                                              bigrams  \
# 0   [(i, have), (have, a), (a, brown), (brown, cat)]
# 1  [(my, friend), (friend, has), (has, a), (a, wh...
# 2  [(my, brother), (brother, has), (has, a), (a, ...
# 3  [(the, apple), (apple, has), (has, turned), (t...
# 4  [(my, sister), (sister, eats), (eats, apple), ...
# 5  [(my, aunt), (aunt, makes), (makes, delicious)...
# 6  [(the, fluffy), (fluffy, dogs), (dogs, and), (...
#
#                                             trigrams  \
# 0  [(i, have, a), (have, a, brown), (a, brown, cat)]
# 1  [(my, friend, has), (friend, has, a), (has, a,...
# 2  [(my, brother, has), (brother, has, a), (has, ...
# 3  [(the, apple, has), (apple, has, turned), (has...
# 4  [(my, sister, eats), (sister, eats, apple), (e...
# 5  [(my, aunt, makes), (aunt, makes, delicious), ...
# 6  [(the, fluffy, dogs), (fluffy, dogs, and), (do...
#
#                           clean_stopwords                clean_stemmed_porter
# 0                            [brown, cat]                        [brown, cat]
# 1                    [friend, white, cat]                [friend, white, cat]
# 2                   [brother, white, car]               [brother, white, car]
# 3                  [apple, turned, brown]                 [appl, turn, brown]
# 4       [sister, eats, apple, every, day]     [sister, eat, appl, everi, day]
# 5    [aunt, makes, delicious, apple, pie]     [aunt, make, delici, appl, pie]
# 6  [fluffy, dogs, brown, hats, favorites]  [fluffi, dog, brown, hat, favorit]

# %%
from nltk.stem import SnowballStemmer

snowball_stemmer = SnowballStemmer('english')

def stemming(text):
    stem_text = []
    for word in text:
        stemmed_word = snowball_stemmer.stem(word)
        stem_text.append(stemmed_word)
    return stem_text

data['clean_stemmed_snowball'] = data['clean_stopwords'].apply(stemming)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data  \
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...
#
#                                              bigrams  \
# 0   [(i, have), (have, a), (a, brown), (brown, cat)]
# 1  [(my, friend), (friend, has), (has, a), (a, wh...
# 2  [(my, brother), (brother, has), (has, a), (a, ...
# 3  [(the, apple), (apple, has), (has, turned), (t...
# 4  [(my, sister), (sister, eats), (eats, apple), ...
# 5  [(my, aunt), (aunt, makes), (makes, delicious)...
# 6  [(the, fluffy), (fluffy, dogs), (dogs, and), (...
#
#                                             trigrams  \
# 0  [(i, have, a), (have, a, brown), (a, brown, cat)]
# 1  [(my, friend, has), (friend, has, a), (has, a,...
# 2  [(my, brother, has), (brother, has, a), (has, ...
# 3  [(the, apple, has), (apple, has, turned), (has...
# 4  [(my, sister, eats), (sister, eats, apple), (e...
# 5  [(my, aunt, makes), (aunt, makes, delicious), ...
# 6  [(the, fluffy, dogs), (fluffy, dogs, and), (do...
#
#                           clean_stopwords                clean_stemmed_porter  \
# 0                            [brown, cat]                        [brown, cat]
# 1                    [friend, white, cat]                [friend, white, cat]
# 2                   [brother, white, car]               [brother, white, car]
# 3                  [apple, turned, brown]                 [appl, turn, brown]
# 4       [sister, eats, apple, every, day]     [sister, eat, appl, everi, day]
# 5    [aunt, makes, delicious, apple, pie]     [aunt, make, delici, appl, pie]
# 6  [fluffy, dogs, brown, hats, favorites]  [fluffi, dog, brown, hat, favorit]
#
#                clean_stemmed_snowball
# 0                        [brown, cat]
# 1                [friend, white, cat]
# 2               [brother, white, car]
# 3                 [appl, turn, brown]
# 4     [sister, eat, appl, everi, day]
# 5     [aunt, make, delici, appl, pie]
# 6  [fluffi, dog, brown, hat, favorit]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\3nauf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def lemmatizer(text):
    lemm_text = []
    for word in text:
        lemmatized_word = wordnet_lemmatizer.lemmatize(word)
        lemm_text.append(lemmatized_word)
    return lemm_text

# %%
data['clean_lemmatized_porter']=data['clean_stemmed_porter'].apply(lemmatizer)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data  \
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...
#
#                                              bigrams  \
# 0   [(i, have), (have, a), (a, brown), (brown, cat)]
# 1  [(my, friend), (friend, has), (has, a), (a, wh...
# 2  [(my, brother), (brother, has), (has, a), (a, ...
# 3  [(the, apple), (apple, has), (has, turned), (t...
# 4  [(my, sister), (sister, eats), (eats, apple), ...
# 5  [(my, aunt), (aunt, makes), (makes, delicious)...
# 6  [(the, fluffy), (fluffy, dogs), (dogs, and), (...
#
#                                             trigrams  \
# 0  [(i, have, a), (have, a, brown), (a, brown, cat)]
# 1  [(my, friend, has), (friend, has, a), (has, a,...
# 2  [(my, brother, has), (brother, has, a), (has, ...
# 3  [(the, apple, has), (apple, has, turned), (has...
# 4  [(my, sister, eats), (sister, eats, apple), (e...
# 5  [(my, aunt, makes), (aunt, makes, delicious), ...
# 6  [(the, fluffy, dogs), (fluffy, dogs, and), (do...
#
#                           clean_stopwords                clean_stemmed_porter  \
# 0                            [brown, cat]                        [brown, cat]
# 1                    [friend, white, cat]                [friend, white, cat]
# 2                   [brother, white, car]               [brother, white, car]
# 3                  [apple, turned, brown]                 [appl, turn, brown]
# 4       [sister, eats, apple, every, day]     [sister, eat, appl, everi, day]
# 5    [aunt, makes, delicious, apple, pie]     [aunt, make, delici, appl, pie]
# 6  [fluffy, dogs, brown, hats, favorites]  [fluffi, dog, brown, hat, favorit]
#
#                clean_stemmed_snowball             clean_lemmatized_porter
# 0                        [brown, cat]                        [brown, cat]
# 1                [friend, white, cat]                [friend, white, cat]
# 2               [brother, white, car]               [brother, white, car]
# 3                 [appl, turn, brown]                 [appl, turn, brown]
# 4     [sister, eat, appl, everi, day]     [sister, eat, appl, everi, day]
# 5     [aunt, make, delici, appl, pie]     [aunt, make, delici, appl, pie]
# 6  [fluffi, dog, brown, hat, favorit]  [fluffi, dog, brown, hat, favorit]

# %%
data['clean_lemmatized_stopwords']=data['clean_stopwords'].apply(lemmatizer)
data
# Out:
#                                               Review  \
# 0                                I have a brown cat.
# 1                         My friend has a White cat.
# 2                        my brother has a white car.
# 3                        The apple has turned brown.
# 4                    My sister eats apple every day.
# 5                 My aunt makes delicious Apple pie.
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                    clean_punctuation  \
# 0                                 I have a brown cat
# 1                          My friend has a White cat
# 2                         my brother has a white car
# 3                         The apple has turned brown
# 4                     My sister eats apple every day
# 5                  My aunt makes delicious Apple pie
# 6  The 3 fluffy dogs AND 2 brown hats are my favo...
#
#                                          clean_lower  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the 3 fluffy dogs and 2 brown hats are my favo...
#
#                                         clean_number  \
# 0                                 i have a brown cat
# 1                          my friend has a white cat
# 2                         my brother has a white car
# 3                         the apple has turned brown
# 4                     my sister eats apple every day
# 5                  my aunt makes delicious apple pie
# 6  the  fluffy dogs and  brown hats are my favorites
#
#                                           token_data  \
# 0                           [i, have, a, brown, cat]
# 1                   [my, friend, has, a, white, cat]
# 2                  [my, brother, has, a, white, car]
# 3                   [the, apple, has, turned, brown]
# 4              [my, sister, eats, apple, every, day]
# 5           [my, aunt, makes, delicious, apple, pie]
# 6  [the, fluffy, dogs, and, brown, hats, are, my,...
#
#                                              bigrams  \
# 0   [(i, have), (have, a), (a, brown), (brown, cat)]
# 1  [(my, friend), (friend, has), (has, a), (a, wh...
# 2  [(my, brother), (brother, has), (has, a), (a, ...
# 3  [(the, apple), (apple, has), (has, turned), (t...
# 4  [(my, sister), (sister, eats), (eats, apple), ...
# 5  [(my, aunt), (aunt, makes), (makes, delicious)...
# 6  [(the, fluffy), (fluffy, dogs), (dogs, and), (...
#
#                                             trigrams  \
# 0  [(i, have, a), (have, a, brown), (a, brown, cat)]
# 1  [(my, friend, has), (friend, has, a), (has, a,...
# 2  [(my, brother, has), (brother, has, a), (has, ...
# 3  [(the, apple, has), (apple, has, turned), (has...
# 4  [(my, sister, eats), (sister, eats, apple), (e...
# 5  [(my, aunt, makes), (aunt, makes, delicious), ...
# 6  [(the, fluffy, dogs), (fluffy, dogs, and), (do...
#
#                           clean_stopwords                clean_stemmed_porter  \
# 0                            [brown, cat]                        [brown, cat]
# 1                    [friend, white, cat]                [friend, white, cat]
# 2                   [brother, white, car]               [brother, white, car]
# 3                  [apple, turned, brown]                 [appl, turn, brown]
# 4       [sister, eats, apple, every, day]     [sister, eat, appl, everi, day]
# 5    [aunt, makes, delicious, apple, pie]     [aunt, make, delici, appl, pie]
# 6  [fluffy, dogs, brown, hats, favorites]  [fluffi, dog, brown, hat, favorit]
#
#                clean_stemmed_snowball             clean_lemmatized_porter  \
# 0                        [brown, cat]                        [brown, cat]
# 1                [friend, white, cat]                [friend, white, cat]
# 2               [brother, white, car]               [brother, white, car]
# 3                 [appl, turn, brown]                 [appl, turn, brown]
# 4     [sister, eat, appl, everi, day]     [sister, eat, appl, everi, day]
# 5     [aunt, make, delici, appl, pie]     [aunt, make, delici, appl, pie]
# 6  [fluffi, dog, brown, hat, favorit]  [fluffi, dog, brown, hat, favorit]
#
#             clean_lemmatized_stopwords
# 0                         [brown, cat]
# 1                 [friend, white, cat]
# 2                [brother, white, car]
# 3               [apple, turned, brown]
# 4    [sister, eats, apple, every, day]
# 5  [aunt, make, delicious, apple, pie]
# 6  [fluffy, dog, brown, hat, favorite]
